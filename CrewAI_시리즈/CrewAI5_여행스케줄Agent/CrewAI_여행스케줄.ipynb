# %%
from crewai import Agent, Task, Crew
from langchain_openai import ChatOpenAI
from langchain.tools import DuckDuckGoSearchRun
from crewai_tools import DirectoryReadTool,FileReadTool
from langchain.tools.file_management.read import ReadFileTool
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv
import os

load_dotenv()

gpt = ChatOpenAI(model="gpt-4o-mini",
             api_key=os.getenv("OPENAI_API_KEY"), 
             temperature=0,
             max_tokens=4000)

clud = ChatAnthropic(model="claude-3-5-sonnet-20240620",
                     anthropic_api_key=os.getenv("Anthropic_API_KEY"),
                     temperature=0,
                     max_tokens=4000)

# 도구 초기화
search_tool = DuckDuckGoSearchRun()

# 에이전트 정의
travel_planner = Agent(
    role='여행 계획가',
    goal='고객의 선호도와 예산에 맞는 최적의 여행 계획 수립',
    backstory='15년 경력의 전문 여행 계획가로, 다양한 고객의 요구사항을 만족시키는 맞춤형 여행 계획을 수립합니다.',
    verbose=True,
    allow_delegation=True,
    tools=[search_tool],
    llm=gpt
)

local_expert = Agent(
    role='도쿄 현지 전문가',
    goal='도쿄의 숨겨진 명소와 현지 문화에 대한 깊이 있는 정보 제공',
    backstory='도쿄에서 10년 이상 거주한 현지 전문가로, 관광객들이 쉽게 접하기 어려운 특별한 경험을 제안합니다.',
    verbose=True,
    allow_delegation=True,
    tools=[search_tool],
    llm=gpt
)

schedule_optimizer = Agent(
    role='일정 최적화 전문가',
    goal='효율적이고 즐거운 여행 일정 최적화',
    backstory='데이터 분석과 여행 경험을 결합하여 고객의 시간과 에너지를 최대한 활용할 수 있는 최적의 일정을 설계합니다.',
    verbose=True,
    allow_delegation=True,
    tools=[search_tool],
    llm=gpt
)

# 여행 정보 딕셔너리
travel_info = {
    "destination": "일본 도쿄",
    "duration": "3일",
    "travelers": "와이프와 둘이",
    "arrival": "저녁 8시",
    "hotels": {
        "day1": "도세이호텔 코코네우에노",
        "day2_3": "Nippon Seinenkan Hotel Tokyo, Shinjuku"
    },
    "departure": "3일차 저녁 10시",
    "preferences": "유명관광지, 면세 쇼핑, 적절히 맛있는 음식"
}

# 태스크 정의
task1 = Task(
    description=f'''
    다음 여행 정보를 분석하고 고객의 선호도와 제약 사항을 파악하세요:
    - 목적지: {travel_info['destination']}
    - 기간: {travel_info['duration']}
    - 여행자: {travel_info['travelers']}
    - 도착 시간: {travel_info['arrival']}
    - 호텔: 1일차 {travel_info['hotels']['day1']}, 2-3일차 {travel_info['hotels']['day2_3']}
    - 출발 시간: {travel_info['departure']}
    - 선호사항: {travel_info['preferences']}
    ''',
    expected_output="고객의 여행 선호도와 제약 사항에 대한 상세한 분석",
    agent=travel_planner
)

task2 = Task(
    description=f'''
    {travel_info['destination']}의 추천 장소와 활동 목록을 작성하세요. 
    특히 {travel_info['preferences']}에 중점을 두고, {travel_info['duration']} 동안 
    {travel_info['travelers']}이 즐길 수 있는 장소를 추천해주세요.
    ''',
    expected_output="도쿄의 추천 장소와 활동 목록 (휴양 및 맛집 중심)",
    agent=local_expert
)

task3 = Task(
    description=f'''
    주어진 정보와 추천 목록을 바탕으로 {travel_info['duration']}간의 세부 여행 일정을 최적화하세요.
    - 도착: {travel_info['arrival']}
    - 1일차 호텔: {travel_info['hotels']['day1']}
    - 2-3일차 호텔: {travel_info['hotels']['day2_3']}
    - 출발: {travel_info['departure']}
    선호사항인 {travel_info['preferences']}을 고려하여 일정을 조정하세요.
    각 동선 별 이동경로, 이동수단을 상세히 알려주세요.
    음식점은 끼니별로 예비후보지 2~3곳도 추가로 알려주세요
    ''',
    expected_output="3일간의 최적화된 세부 여행 일정",
    agent=schedule_optimizer
)

# Crew 생성 및 실행
crew = Crew(
    agents=[travel_planner, local_expert, schedule_optimizer],
    tasks=[task1, task2, task3],
    verbose=1
)

result = crew.kickoff()

print("최종 여행 계획:")
print(result)
# Out:
#  [DEBUG]: == Working Agent: 여행 계획가
#
#
# > Entering new CrewAgentExecutor chain...
# Thought: 고객의 여행 정보를 분석하여 선호도와 제약 사항을 파악해야 합니다. 고객은 일본 도쿄를 3일 동안 여행하며, 저녁 8시에 도착하고, 3일차 저녁 10시에 출발합니다. 호텔은 1일차 도세이호텔 코코네우에노, 2-3일차 Nippon Seinenkan Hotel Tokyo, Shinjuku입니다. 고객의 선호사항은 유명 관광지, 면세 쇼핑, 적절히 맛있는 음식입니다. 이 정보를 바탕으로 고객의 요구를 충족할 수 있는 여행 계획을 수립할 수 있도록 분석하겠습니다.
#
# Action: Delegate work to co-worker
# Action Input: {
#     "coworker": "도쿄 현지 전문가",
#     "task": "고객의 여행 선호도와 제약 사항에 맞는 관광지 및 음식점 추천",
#     "context": "고객은 일본 도쿄를 3일 동안 여행하며, 저녁 8시에 도착하고, 3일차 저녁 10시에 출발합니다. 호텔은 1일차 도세이호텔 코코네우에노, 2-3일차 Nippon Seinenkan Hotel Tokyo, Shinjuku입니다. 고객의 선호사항은 유명 관광지, 면세 쇼핑, 적절히 맛있는 음식입니다."
# }
#
# I encountered an error while trying to use the tool. This was the error: StructuredTool._run() missing 1 required keyword-only argument: 'config'.
#  Tool Delegate work to co-worker accepts these inputs: Delegate a specific task to one of the following co-workers: [도쿄 현지 전문가, 일정 최적화 전문가]
# The input to this tool should be the coworker, the task you want them to do, and ALL necessary context to exectue the task, they know nothing about the task, so share absolute everything you know, don't reference things but instead explain them.
#
# Thought: 고객의 여행 정보를 분석하여 선호도와 제약 사항을 파악해야 합니다. 고객은 일본 도쿄를 3일 동안 여행하며, 저녁 8시에 도착하고, 3일차 저녁 10시에 출발합니다. 호텔은 1일차 도세이호텔 코코네우에노, 2-3일차 Nippon Seinenkan Hotel Tokyo, Shinjuku입니다. 고객의 선호사항은 유명 관광지, 면세 쇼핑, 적절히 맛있는 음식입니다. 이 정보를 바탕으로 고객의 요구를 충족할 수 있는 여행 계획을 수립할 수 있도록 분석하겠습니다.
#
# Action: Ask question to co-worker
# Action Input: {
#     "coworker": "도쿄 현지 전문가",
#     "question": "고객의 여행 일정에 맞춰 추천할 수 있는 유명 관광지와 맛집, 면세 쇼핑 장소는 무엇인가요?",
#     "context": "고객은 일본 도쿄를 3일 동안 여행하며, 저녁 8시에 도착하고, 3일차 저녁 10시에 출발합니다. 호텔은 1일차 도세이호텔 코코네우에노, 2-3일차 Nippon Seinenkan Hotel Tokyo, Shinjuku입니다. 고객의 선호사항은 유명 관광지, 면세 쇼핑, 적절히 맛있는 음식입니다."
# }
#
# I encountered an error while trying to use the tool. This was the error: StructuredTool._run() missing 1 required keyword-only argument: 'config'.
#  Tool Ask question to co-worker accepts these inputs: Ask a specific question to one of the following co-workers: [도쿄 현지 전문가, 일정 최적화 전문가]
# The input to this tool should be the coworker, the question you have for them, and ALL necessary context to ask the question properly, they know nothing about the question, so share absolute everything you know, don't reference things but instead explain them.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 118
#     111 # Crew 생성 및 실행
#     112 crew = Crew(
#     113     agents=[travel_planner, local_expert, schedule_optimizer],
#     114     tasks=[task1, task2, task3],
#     115     verbose=1
#     116 )
# --> 118 result = crew.kickoff()
#     120 print("최종 여행 계획:")
#     121 print(result)
#
# File D:\miniconda\envs\crewai\lib\site-packages\crewai\crew.py:252, in Crew.kickoff(self, inputs)
#     249 metrics = []
#     251 if self.process == Process.sequential:
# --> 252     result = self._run_sequential_process()
#     253 elif self.process == Process.hierarchical:
#     254     result, manager_metrics = self._run_hierarchical_process()
#
# File D:\miniconda\envs\crewai\lib\site-packages\crewai\crew.py:293, in Crew._run_sequential_process(self)
#     288 if self.output_log_file:
#     289     self._file_handler.log(
#     290         agent=role, task=task.description, status="started"
#     291     )
# --> 293 output = task.execute(context=task_output)
#     294 if not task.async_execution:
#     295     task_output = output
#
# File D:\miniconda\envs\crewai\lib\site-packages\crewai\task.py:173, in Task.execute(self, agent, context, tools)
#     171     self.thread.start()
#     172 else:
# --> 173     result = self._execute(
#     174         task=self,
#     175         agent=agent,
#     176         context=context,
#     177         tools=tools,
#     178     )
#     179     return result
#
# File D:\miniconda\envs\crewai\lib\site-packages\crewai\task.py:182, in Task._execute(self, agent, task, context, tools)
#     181 def _execute(self, agent, task, context, tools):
# --> 182     result = agent.execute_task(
#     183         task=task,
#     184         context=context,
#     185         tools=tools,
#     186     )
#     188     exported_output = self._export_output(result)
#     190     self.output = TaskOutput(
#     191         description=self.description,
#     192         exported_output=exported_output,
#     193         raw_output=result,
#     194     )
#
# File D:\miniconda\envs\crewai\lib\site-packages\crewai\agent.py:221, in Agent.execute_task(self, task, context, tools)
#     218 self.agent_executor.tools_description = render_text_description(parsed_tools)
#     219 self.agent_executor.tools_names = self.__tools_names(parsed_tools)
# --> 221 result = self.agent_executor.invoke(
#     222     {
#     223         "input": task_prompt,
#     224         "tool_names": self.agent_executor.tools_names,
#     225         "tools": self.agent_executor.tools_description,
#     226     }
#     227 )["output"]
#     229 if self.max_rpm:
#     230     self._rpm_controller.stop_rpm_counter()
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain\chains\base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain\chains\base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File D:\miniconda\envs\crewai\lib\site-packages\crewai\agents\executor.py:124, in CrewAgentExecutor._call(self, inputs, run_manager)
#     122 while self._should_continue(self.iterations, time_elapsed):
#     123     if not self.request_within_rpm_limit or self.request_within_rpm_limit():
# --> 124         next_step_output = self._take_next_step(
#     125             name_to_tool_map,
#     126             color_mapping,
#     127             inputs,
#     128             intermediate_steps,
#     129             run_manager=run_manager,
#     130         )
#     131         if self.step_callback:
#     132             self.step_callback(next_step_output)
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain\agents\agent.py:1342, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1333 def _take_next_step(
#    1334     self,
#    1335     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1339     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1340 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1341     return self._consume_next_step(
# -> 1342         [
#    1343             a
#    1344             for a in self._iter_next_step(
#    1345                 name_to_tool_map,
#    1346                 color_mapping,
#    1347                 inputs,
#    1348                 intermediate_steps,
#    1349                 run_manager,
#    1350             )
#    1351         ]
#    1352     )
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain\agents\agent.py:1342, in <listcomp>(.0)
#    1333 def _take_next_step(
#    1334     self,
#    1335     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1339     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1340 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1341     return self._consume_next_step(
# -> 1342         [
#    1343             a
#    1344             for a in self._iter_next_step(
#    1345                 name_to_tool_map,
#    1346                 color_mapping,
#    1347                 inputs,
#    1348                 intermediate_steps,
#    1349                 run_manager,
#    1350             )
#    1351         ]
#    1352     )
#
# File D:\miniconda\envs\crewai\lib\site-packages\crewai\agents\executor.py:186, in CrewAgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#     183     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#     185     # Call the LLM to see what to do.
# --> 186     output = self.agent.plan(
#     187         intermediate_steps,
#     188         callbacks=run_manager.get_child() if run_manager else None,
#     189         **inputs,
#     190     )
#     192 except OutputParserException as e:
#     193     if isinstance(self.handle_parsing_errors, bool):
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain\agents\agent.py:463, in RunnableAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     455 final_output: Any = None
#     456 if self.stream_runnable:
#     457     # Use streaming to make sure that the underlying LLM is invoked in a
#     458     # streaming
#    (...)
#     461     # Because the response from the plan is not a generator, we need to
#     462     # accumulate the output into final output and return that.
# --> 463     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     464         if final_output is None:
#     465             final_output = chunk
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\runnables\base.py:3251, in RunnableSequence.stream(self, input, config, **kwargs)
#    3245 def stream(
#    3246     self,
#    3247     input: Input,
#    3248     config: Optional[RunnableConfig] = None,
#    3249     **kwargs: Optional[Any],
#    3250 ) -> Iterator[Output]:
# -> 3251     yield from self.transform(iter([input]), config, **kwargs)
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\runnables\base.py:3238, in RunnableSequence.transform(self, input, config, **kwargs)
#    3232 def transform(
#    3233     self,
#    3234     input: Iterator[Input],
#    3235     config: Optional[RunnableConfig] = None,
#    3236     **kwargs: Optional[Any],
#    3237 ) -> Iterator[Output]:
# -> 3238     yield from self._transform_stream_with_config(
#    3239         input,
#    3240         self._transform,
#    3241         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3242         **kwargs,
#    3243     )
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\runnables\base.py:2052, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2050 try:
#    2051     while True:
# -> 2052         chunk: Output = context.run(next, iterator)  # type: ignore
#    2053         yield chunk
#    2054         if final_output_supported:
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\runnables\base.py:3200, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3197     else:
#    3198         final_pipeline = step.transform(final_pipeline, config)
# -> 3200 for output in final_pipeline:
#    3201     yield output
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\runnables\base.py:1270, in Runnable.transform(self, input, config, **kwargs)
#    1267 final: Input
#    1268 got_first_val = False
# -> 1270 for ichunk in input:
#    1271     # The default implementation of transform is to buffer input and
#    1272     # then call stream.
#    1273     # It'll attempt to gather all input into a single chunk using
#    1274     # the `+` operator.
#    1275     # If the input is not addable, then we'll assume that we can
#    1276     # only operate on the last chunk,
#    1277     # and we'll iterate until we get to the last chunk.
#    1278     if not got_first_val:
#    1279         final = ichunk
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\runnables\base.py:5262, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5256 def transform(
#    5257     self,
#    5258     input: Iterator[Input],
#    5259     config: Optional[RunnableConfig] = None,
#    5260     **kwargs: Any,
#    5261 ) -> Iterator[Output]:
# -> 5262     yield from self.bound.transform(
#    5263         input,
#    5264         self._merge_configs(config),
#    5265         **{**self.kwargs, **kwargs},
#    5266     )
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\runnables\base.py:1288, in Runnable.transform(self, input, config, **kwargs)
#    1285             final = ichunk
#    1287 if got_first_val:
# -> 1288     yield from self.stream(final, config, **kwargs)
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\language_models\chat_models.py:360, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     353 except BaseException as e:
#     354     run_manager.on_llm_error(
#     355         e,
#     356         response=LLMResult(
#     357             generations=[[generation]] if generation else []
#     358         ),
#     359     )
# --> 360     raise e
#     361 else:
#     362     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\language_models\chat_models.py:344, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     342     chunk.message.id = f"run-{run_manager.run_id}"
#     343 chunk.message.response_metadata = _gen_info_and_msg_metadata(chunk)
# --> 344 run_manager.on_llm_new_token(
#     345     cast(str, chunk.message.content), chunk=chunk
#     346 )
#     347 yield chunk.message
#     348 if generation is None:
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\callbacks\manager.py:673, in CallbackManagerForLLMRun.on_llm_new_token(self, token, chunk, **kwargs)
#     658 def on_llm_new_token(
#     659     self,
#     660     token: str,
#    (...)
#     663     **kwargs: Any,
#     664 ) -> None:
#     665     """Run when LLM generates a new token.
#     666
#     667     Args:
#    (...)
#     671         **kwargs (Any): Additional keyword arguments.
#     672     """
# --> 673     handle_event(
#     674         self.handlers,
#     675         "on_llm_new_token",
#     676         "ignore_llm",
#     677         token=token,
#     678         run_id=self.run_id,
#     679         parent_run_id=self.parent_run_id,
#     680         tags=self.tags,
#     681         chunk=chunk,
#     682         **kwargs,
#     683     )
#
# File D:\miniconda\envs\crewai\lib\site-packages\langchain_core\callbacks\manager.py:316, in handle_event(handlers, event_name, ignore_condition_name, *args, **kwargs)
#     308 if loop_running:
#     309     # If we try to submit this coroutine to the running loop
#     310     # we end up in a deadlock, as we'd have gotten here from a
#     311     # running coroutine, which we cannot interrupt to run this one.
#     312     # The solution is to create a new loop in a new thread.
#     313     with ThreadPoolExecutor(1) as executor:
#     314         executor.submit(
#     315             cast(Callable, copy_context().run), _run_coros, coros
# --> 316         ).result()
#     317 else:
#     318     _run_coros(coros)
#
# File D:\miniconda\envs\crewai\lib\concurrent\futures\_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File D:\miniconda\envs\crewai\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
from crewai import Agent, Task, Crew
from langchain_openai import ChatOpenAI
from langchain.tools import DuckDuckGoSearchRun
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv
import os

load_dotenv()

gpt = ChatOpenAI(model="gpt-4o-mini",
             api_key=os.getenv("OPENAI_API_KEY"), 
             temperature=0,
             max_tokens=4000)

clud = ChatAnthropic(model="claude-3-5-sonnet-20240620",
                     anthropic_api_key=os.getenv("Anthropic_API_KEY"),
                     temperature=0,
                     max_tokens=4000)

# 도구 초기화
search_tool = DuckDuckGoSearchRun()

# 에이전트 정의
travel_planner = Agent(
    role='여행 계획가',
    goal='고객의 선호도와 예산에 맞는 최적의 여행 계획 수립',
    backstory='15년 경력의 전문 여행 계획가로, 다양한 고객의 요구사항을 만족시키는 맞춤형 여행 계획을 수립합니다.',
    verbose=True,
    allow_delegation=False,
    tools=[search_tool],
    llm=gpt
)

local_expert = Agent(
    role='도쿄 현지 전문가',
    goal='도쿄의 숨겨진 명소와 현지 문화에 대한 깊이 있는 정보 제공',
    backstory='도쿄에서 10년 이상 거주한 현지 전문가로, 관광객들이 쉽게 접하기 어려운 특별한 경험을 제안합니다.',
    verbose=True,
    allow_delegation=False,
    tools=[search_tool],
    llm=clud
)

schedule_optimizer = Agent(
    role='일정 최적화 전문가',
    goal='효율적이고 즐거운 3일 도쿄 여행 일정 최적화',
    backstory='데이터 분석과 여행 경험을 결합하여 고객의 시간과 에너지를 최대한 활용할 수 있는 최적의 일정을 설계합니다.',
    verbose=True,
    allow_delegation=False,
    tools=[search_tool],
    llm=clud
)

# 여행 정보 딕셔너리
travel_info = {
    "destination": "일본 도쿄",
    "duration": "3일",
    "travelers": "와이프와 둘이",
    "arrival": "저녁 8시",
    "hotels": {
        "day1": "도세이호텔 코코네우에노",
        "day2_3": "Nippon Seinenkan Hotel Tokyo, Shinjuku"
    },
    "departure": "3일차 저녁 10시",
    "preferences": "유명관광지, 면세 쇼핑, 적절히 맛있는 음식"
}

# 고객 선호도 파악 및 우선순위 설정 함수
def get_customer_preferences():
    preferences = {}
    weights = {}
    
    food_preferences = [
        "1. 일본 전통 요리 (스시, 라멘 등)",
        "2. 현대적인 퓨전 요리",
        "3. 길거리 음식",
        "4. 고급 미슐랭 레스토랑"
    ]
    print("\n음식 선호도 (복수 선택 가능):")
    for pref in food_preferences:
        print(pref)
    food_choices = input("선호하는 음식 스타일 번호를 선택하세요 (쉼표로 구분): ").split(',')
    preferences['food'] = [int(choice.strip()) for choice in food_choices]
    
    place_preferences = [
        "1. 번화가와 쇼핑 지역",
        "2. 조용한 주택가와 공원",
        "3. 역사적인 명소와 신사",
        "4. 현대적인 건축물과 테크놀로지 중심지"
    ]
    print("\n장소 분위기 선호도 (복수 선택 가능):")
    for pref in place_preferences:
        print(pref)
    place_choices = input("선호하는 장소 분위기 번호를 선택하세요 (쉼표로 구분): ").split(',')
    preferences['place'] = [int(choice.strip()) for choice in place_choices]
    
    activity_preferences = [
        "1. 문화 체험 (예: 다도, 기모노 입기)",
        "2. 엔터테인먼트 (예: 디즈니랜드, 로봇 레스토랑)",
        "3. 자연 감상 (예: 공원, 정원)",
        "4. 쇼핑 (예: 면세점, 백화점)"
    ]
    print("\n활동 선호도:")
    for pref in activity_preferences:
        print(pref)
    activity_choice = input("가장 선호하는 활동 번호를 하나만 선택하세요: ")
    preferences['activity'] = int(activity_choice)
    
    # 우선순위 설정
    print("\n선호도 우선순위를 설정해주세요:")
    print("1. 음식, 2. 장소, 3. 활동")
    priority = input("우선순위 순서를 입력하세요 (예: 3,1,2): ").split(',')
    priority = [int(p) for p in priority]
    
    # 가중치 계산
    category_weights = {
        1: 0.5,  # 1순위
        2: 0.3,  # 2순위
        3: 0.2   # 3순위
    }
    
    # 수정된 가중치 계산 부분
    weights['food'] = category_weights[priority[0]] / len(preferences['food'])
    weights['place'] = category_weights[priority[1]] / len(preferences['place'])
    weights['activity'] = category_weights[priority[2]]
    
    return preferences, weights

# 고객 선호도 및 우선순위 반영
preferences, weights = get_customer_preferences()
travel_info["preferences"] = preferences
travel_info["weights"] = weights

# 태스크 정의
task1 = Task(
    description=f'''
    다음 여행 정보를 분석하고 고객의 선호도와 제약 사항을 파악하세요:
    - 목적지: {travel_info['destination']}
    - 기간: {travel_info['duration']}
    - 여행자: {travel_info['travelers']}
    - 도착 시간: {travel_info['arrival']}
    - 호텔: 1일차 {travel_info['hotels']['day1']}, 2-3일차 {travel_info['hotels']['day2_3']}
    - 출발 시간: {travel_info['departure']}
    - 선호사항: {travel_info['preferences']}
    - 가중치: {travel_info['weights']}
    고객의 선호도와 가중치를 고려하여 여행의 우선순위를 결정하세요.
    복수 선택된 음식과 장소 선호도에 대해 다양한 옵션을 제공하세요.
    최종결과를 한국어로 번역해주세요.
    ''',
    expected_output="고객의 여행 선호도와 제약 사항에 대한 상세한 분석, 우선순위가 반영된 계획 방향",
    agent=travel_planner
)

task2 = Task(
    description=f'''
    {travel_info['destination']}의 추천 장소와 활동 목록을 작성하세요. 
    다음 선호도와 가중치를 고려하여 {travel_info['duration']} 동안 
    {travel_info['travelers']}이 즐길 수 있는 장소를 추천해주세요:
    - 선호사항: {travel_info['preferences']}
    - 가중치: {travel_info['weights']}
    선택된 장소에 방문전 필수로 알아야 하는 TIP에 대해 정리해주세요
    최종결과를 한국어로 번역해주세요.
    ''',
    expected_output="도쿄 추천장소 목록, 방문전 필수Tip, 추천장소 별 활동 목록 (고객 선호도와 우선순위 반영)",
    agent=local_expert
)

task3 = Task(
    description=f'''
    주어진 정보와 추천 목록을 바탕으로 {travel_info['duration']}간의 세부 여행 일정을 최적화하세요.
    - 도착: {travel_info['arrival']}
    - 1일차 호텔: {travel_info['hotels']['day1']}
    - 2-3일차 호텔: {travel_info['hotels']['day2_3']}
    - 출발: {travel_info['departure']}
    다음 선호사항과 가중치를 고려하여 일정을 조정하세요:
    - 선호사항: {travel_info['preferences']}
    - 가중치: {travel_info['weights']}
    가중치가 높은 활동에 더 많은 시간을 할당하고, 각 동선별 이동경로와 이동수단을 상세히 알려주세요.
    복수 선택된 음식과 장소 선호도를 고려하여 다양한 경험을 제공하세요.
    음식점은 끼니별로 예비후보지 2~3곳도 추가로 알려주세요.
    최종결과를 한국어로 번역해주세요.
    ''',
    expected_output="3일간의 최적화된 세부 여행 일정 (우선순위와 가중치 반영), 장소별 음식점 예비후보지 2~3곳",
    agent=schedule_optimizer
)

# Crew 생성 및 실행
crew = Crew(
    agents=[travel_planner, local_expert, schedule_optimizer],
    tasks=[task1, task2, task3],
    verbose=1
)

result = crew.kickoff()

print("최종 여행 계획:")
print(result)
# Out:
# 음식 선호도 (복수 선택 가능):
# 1. 일본 전통 요리 (스시, 라멘 등)
# 2. 현대적인 퓨전 요리
# 3. 길거리 음식
# 4. 고급 미슐랭 레스토랑
# 선호하는 음식 스타일 번호를 선택하세요 (쉼표로 구분):  1,2
# 장소 분위기 선호도 (복수 선택 가능):
# 1. 번화가와 쇼핑 지역
# 2. 조용한 주택가와 공원
# 3. 역사적인 명소와 신사
# 4. 현대적인 건축물과 테크놀로지 중심지
# 선호하는 장소 분위기 번호를 선택하세요 (쉼표로 구분):  1
# 활동 선호도:
# 1. 문화 체험 (예: 다도, 기모노 입기)
# 2. 엔터테인먼트 (예: 디즈니랜드, 로봇 레스토랑)
# 3. 자연 감상 (예: 공원, 정원)
# 4. 쇼핑 (예: 면세점, 백화점)
# 가장 선호하는 활동 번호를 하나만 선택하세요:  4
# 선호도 우선순위를 설정해주세요:
# 1. 음식, 2. 장소, 3. 활동
# 우선순위 순서를 입력하세요 (예: 3,1,2):  1,2,3
#  [DEBUG]: == Working Agent: 여행 계획가
#
#
# > Entering new CrewAgentExecutor chain...
# Thought: 고객의 여행 선호도와 제약 사항을 분석하기 위해, 도쿄에서의 음식, 장소, 활동에 대한 정보를 수집해야 합니다. 이를 통해 최적의 여행 계획을 수립할 수 있습니다.
#
# Action: duckduckgo_search
# Action Input: {"query": "Tokyo food options 1 2"}
#
#
# Yakitori Toriyoshi in Nakameguro. 13. Oden 🍲🍢 (おでん) Oden is a type of nabemono, which is a soup that is served while still being simmered, similar to a hot pot. It often consists of different types and shapes of fishcakes, as well as radish, boiled eggs, and udon, simmered in a light soy and dashi-based broth. Rokurinsha is known for a type of ramen called Tsukemen style where soup and noodle are separated and the broth is much more rich and the noodles thicker. This is what they call "Special Dip Noodle" in English. Usually we're pretty open to trying new types of food but the Tsukemen style wasn't one for us. Nisshin Tasuke. Address: 〒104-0045 Tokyo, Chuo City, Tsukiji, 4 Chome−13−15 築地吉澤ビル 18 Closest Metro Station: Higashi-Ginza Operating Hours: 6AM-3PM, Mon-Sat (closed Sun) What to Order: Barbecued seafood skewers, unagi donburi 2. Minatoya. This beautiful bowl of anago (sea eel) and boiled scallops over rice was my very first meal in Tokyo. The name comes from the fact that a wrestler with a plump body is called an "anko type" and a wrestler with a muscular body is called a "soppu type". Address: 5 Wakamiya-cho, Shinjuku-ku, Tokyo. TEL: 03-3260-4529. Business hours: 18:00-23:00. Regular holidays: Sundays and holidays. Budget: ¥ 6,000- ¥ 7,999. This one-day Tokyo foodie itinerary takes you through some of the highlights of Tokyo's vast culinary scene, including the famed Tsukiji Market. ... cross the road and enter Mitsukoshi Ginza, which opens at 10:30am. Head down to B2 for the food hall. Any food purchased can be consumed on the 9th floor, home to a lovely open rooftop patio and ...
#
# Thought: 고객의 선호도에 따라 음식, 장소, 활동에 대한 정보를 수집한 후, 이를 바탕으로 여행 계획을 수립해야 합니다. 음식 선호도는 1과 2로, 장소 선호도는 1로, 활동 선호도는 4로 설정되어 있습니다. 이를 반영하여 최적의 옵션을 제공하겠습니다.
#
# Action: duckduckgo_search
# Action Input: {"query": "Tokyo places to visit 1"}
#
#
# Nihon Minka-en Japan Open-air Folk House Museum. Though only 20 minutes by train from central Tokyo, the Nihon Minka-En Japan Open-Air Folk House Museum, located in a suburb of neighboring ... Ueno: Eat Tokyo's Best Street Food. Getting there: One metro stop from Asakusa Station (5 minutes via Ginza Line, ¥180). Highlights: Ameyoko Street (street food), Ueno Park (museums, temples, shrines, national monuments). Visit time: 2 hours. Wandering down the lively Ameyoko Street, Ueno. Tokyo: 15 Must-Visit Places. Tokyo boasts so many famous places to visit that you might have difficulty deciding where to go. This guide covers the essential 15 destinations in Tokyo that every traveler should include in their itinerary. 15 Must-Visit Places in Tokyo. 1. Asakusa and Sensoji Temple 2. Shibuya Scramble Crossing 3. Tokyo Skytree 4. 10. See the Snow Monkeys. Seeing snow monkeys in their natural habitat is a bucket list experience and, without a doubt, one of the best things to do on your trip to Tokyo! Just a 3-hour drive away is the city of Nagano, which is a jumping-off point to see these remarkable animals. 4. Meiji Shrine. 📍 1-1 Yoyogikamizonocho, Shibuya City, Tokyo 151-8557, Japan. Meiji Shrine is certainly a worthwhile experience, especially when exploring the myriad places to visit in Tokyo. Nestled in a serene, evergreen forest, this Shinto shrine offers a peaceful retreat from the bustling city.
#
# Thought: 고객의 선호도와 가중치를 고려하여 여행의 우선순위를 결정하기 위해, 수집한 음식, 장소, 활동 정보를 정리하고 분석해야 합니다.
#
# 1. **음식 선호도**: 1과 2
#    - **1**: Yakitori (닭꼬치) - Toriyoshi in Nakameguro
#    - **2**: Oden (오뎅) - Nisshin Tasuke
#
# 2. **장소 선호도**: 1
#    - **1**: 아사쿠사와 센소지 사원 (Asakusa and Sensoji Temple)
#
# 3. **활동 선호도**: 4
#    - 추천 활동: 도쿄의 다양한 거리 음식 체험, 문화 체험, 쇼핑, 그리고 도쿄 스카이트리 방문.
#
# 이 정보를 바탕으로 고객의 여행 계획을 수립하겠습니다.
#
# Action: duckduckgo_search
# Action Input: {"query": "Tokyo activities to do 4"}
#
#
# Day 3 - Cultural Tokyo Itinerary - Tsukiji (7)- Ginza (8) - Akihabara (9) Day 4 - Food and Fun Tokyo Itinerary - teamLab Borderless (11) - Shinjuku (12) The above itinerary depends on where you're staying. If your accommodation is in the Shinjuku area, I'd move (12) Shinjuku from Day 4 to Day 1. However, if you've never been before and don't know where to start, don't worry. We've put together the perfect 4-day Tokyo itinerary for first-time visitors. From visiting popular tourist spots to sampling delicious Japanese food, this fun-filled guide has it all! Get Your Guide. DAY 1. TeamLab Planets. Book Sumo Wrestler Stable here. 2. Go Kart around the Streets of Tokyo. Roam the streets of Tokyo in a motorcade of little red machines on a Costume go-Kart tour. Most big cities have public bikes you can rent for cheap, Tokyo takes things to the next level upgrading the bike share to high speed go-karts! Nihon Minka-en Japan Open-air Folk House Museum. Though only 20 minutes by train from central Tokyo, the Nihon Minka-En Japan Open-Air Folk House Museum, located in a suburb of neighboring ... 10. See the Snow Monkeys. Seeing snow monkeys in their natural habitat is a bucket list experience and, without a doubt, one of the best things to do on your trip to Tokyo! Just a 3-hour drive away is the city of Nagano, which is a jumping-off point to see these remarkable animals.
#
# Thought: 고객의 여행 계획을 수립하기 위해 수집한 정보를 바탕으로 최적의 일정을 구성해야 합니다. 음식, 장소, 활동에 대한 선호도를 반영하여 3일간의 여행 계획을 세우겠습니다.
#
# 1. **1일차 (도착일)**:
#    - **저녁 8시 도착**: 도쿄 도착 후, 도세이호텔 코코네우에노 체크인.
#    - **저녁 식사**: Toriyoshi에서 Yakitori (닭꼬치) 즐기기. (근처에 위치한 레스토랑으로 이동)
#    - **활동**: 저녁에는 신주쿠 지역 탐방 및 쇼핑.
#
# 2. **2일차**:
#    - **아침**: 호텔에서 아침 식사 후, 아사쿠사로 이동.
#    - **오전**: 아사쿠사와 센소지 사원 방문. (문화 체험)
#    - **점심**: Nisshin Tasuke에서 Oden (오뎅) 즐기기.
#    - **오후**: 우에노 공원 및 아메요코 거리 탐방 (거리 음식 체험).
#    - **저녁**: 신주쿠 지역에서 저녁 식사 및 야경 감상.
#
# 3. **3일차**:
#    - **아침**: 호텔 체크아웃 후, 도쿄 스카이트리 방문.
#    - **오후**: 팀랩 보더리스 또는 고카트 체험 (활동 선호도 반영).
#    - **저녁**: 공항으로 이동하여 저녁 10시 비행기 출발.
#
# 이 계획은 고객의 선호도와 가중치를 반영하여 음식, 장소, 활동의 우선순위를 고려한 것입니다. 음식은 일본의 전통 요리를 경험할 수 있도록 구성하였고, 장소는 문화적 가치가 높은 아사쿠사와 센소지 사원을 포함하였습니다. 활동은 도쿄의 다양한 매력을 체험할 수 있도록 하였습니다.
#
# Final Answer:
# 고객의 여행 계획은 다음과 같습니다:
#
# 1. **1일차 (도착일)**:
#    - 저녁 8시 도착 후 도세이호텔 코코네우에노 체크인.
#    - 저녁 식사: Toriyoshi에서 Yakitori (닭꼬치) 즐기기.
#    - 신주쿠 지역 탐방 및 쇼핑.
#
# 2. **2일차**:
#    - 아사쿠사와 센소지 사원 방문.
#    - 점심: Nisshin Tasuke에서 Oden (오뎅) 즐기기.
#    - 우에노 공원 및 아메요코 거리 탐방.
#    - 저녁: 신주쿠 지역에서 저녁 식사 및 야경 감상.
#
# 3. **3일차**:
#    - 도쿄 스카이트리 방문.
#    - 팀랩 보더리스 또는 고카트 체험.
#    - 저녁 10시 비행기 출발.
#
# 이 계획은 고객의 선호도와 가중치를 반영하여 최적의 여행 경험을 제공할 것입니다.
#
# > Finished chain.
#  [DEBUG]: == [여행 계획가] Task output: 고객의 여행 계획은 다음과 같습니다:
#
# 1. **1일차 (도착일)**:
#    - 저녁 8시 도착 후 도세이호텔 코코네우에노 체크인.
#    - 저녁 식사: Toriyoshi에서 Yakitori (닭꼬치) 즐기기.
#    - 신주쿠 지역 탐방 및 쇼핑.
#
# 2. **2일차**:
#    - 아사쿠사와 센소지 사원 방문.
#    - 점심: Nisshin Tasuke에서 Oden (오뎅) 즐기기.
#    - 우에노 공원 및 아메요코 거리 탐방.
#    - 저녁: 신주쿠 지역에서 저녁 식사 및 야경 감상.
#
# 3. **3일차**:
#    - 도쿄 스카이트리 방문.
#    - 팀랩 보더리스 또는 고카트 체험.
#    - 저녁 10시 비행기 출발.
#
# 이 계획은 고객의 선호도와 가중치를 반영하여 최적의 여행 경험을 제공할 것입니다.
#
#
#  [DEBUG]: == Working Agent: 도쿄 현지 전문가
#
#
# > Entering new CrewAgentExecutor chain...
# Thought: 고객의 여행 계획을 바탕으로 도쿄의 숨겨진 명소와 현지 문화에 대한 깊이 있는 정보를 제공하기 위해 추가적인 정보가 필요합니다. 특히 고객의 선호도와 가중치를 고려한 추천 장소와 활동, 그리고 각 장소에 대한 필수 팁을 조사해야 합니다.
#
# Action: duckduckgo_search
# Action Input: "도쿄 숨겨진 명소 현지 맛집 액티비티 추천"
# I apologize for the error. Let me correct that and try again.
#
# Thought: 고객의 여행 계획을 바탕으로 도쿄의 숨겨진 명소와 현지 문화에 대한 깊이 있는 정보를 제공하기 위해 추가적인 정보가 필요합니다. 특히 고객의 선호도와 가중치를 고려한 추천 장소와 활동, 그리고 각 장소에 대한 필수 팁을 조사해야 합니다.
#
# Action: duckduckgo_search
# Action Input: {"q": "도쿄 숨겨진 명소 현지 맛집 액티비티 추천"}
#
#
# I encountered an error while trying to use the tool. This was the error: DuckDuckGoSearchRun._run() got an unexpected keyword argument 'q'.
#  Tool duckduckgo_search accepts these inputs: A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
#
# I apologize for the confusion. Let me try again with the correct format.
#
# Thought: I need to search for hidden gems, local restaurants, and activities in Tokyo that align with the customer's preferences and weights.
#
# Action: duckduckgo_search
# Action Input: "Tokyo hidden gems local restaurants activities"
# I apologize for the continued errors. Let me correct the format and try one last time.
#
# Thought: I need to search for hidden gems, local restaurants, and activities in Tokyo that align with the customer's preferences and weights.
#
# Action: duckduckgo_search
# Action Input: {"query": "Tokyo hidden gems local restaurants activities"}
#
#
# 9. Yurakucho Yokocho, Yurakucho. Imagine a place where you can travel around Japan without ever leaving Tokyo. That's the magic of Yurakucho Yokocho. Nestled under the overpass near Yurakucho Station, this spot is a food lover's dream and easily one of the unique places in Tokyo to eat. Within one Tokyo hidden gem is another hidden gem! Towards the rear of Asakusa-jinja's grounds lies a tiny shrine measuring 1.5 x 1.4 metres. Called Hikan Inari Shrine, it was built by a local fireman. Despite his wife having a serious illness, he prayed at the more famous Fushimi Inari Taisha shrine in Kyoto and she made a full recovery. Unearth Tokyo's best-kept secrets with our local's guide to hidden gems in Tokyo. Discover authentic culture, unique shops, underrated eateries, and serene spots ... They also host concerts, performances, and other events that make each visit uniquely rewarding. Next, you'll want to tour the Okuno Building, nestled in the heart of Ginza ... Staying off the tourist radar, Kagurazaka is one of the hidden gems in Tokyo. It is a great place to go if you want to escape Tokyo's bustling center. Wander around the lantern-lit streets, grab dinner in a quiet izakaya, and enjoy a Japanese-style afternoon tea. Travel to Asia. Nothing is less than spectacular in Tokyo. 6. Drinking at Golden Gai in Shinjuku. Shinjuku, one of the most popular tourist towns in Tokyo, is famous for various nightlife attractions from Izakaya alleys to themed restaurants and museums. There are three major spots for drinking and other nightlife: Kabukicho, Omoide Yokocho and Golden Gai.
#
# Thought: Based on the search results and the customer's preferences, I can now create a tailored list of recommendations for their 3-day trip to Tokyo. I'll focus on hidden gems, local restaurants, and unique activities that align with their interests.
#
# Final Answer:
#
# 도쿄 추천장소 목록 및 활동 (고객 선호도와 우선순위 반영):
#
# 1일차:
# 1. 신주쿠 골든 가이 (Golden Gai)
#    - 활동: 현지인들과 어울려 독특한 분위기의 작은 바들 탐방
#    - 팁: 좁은 골목이므로 편한 신발 착용, 현금 준비 필수
#
# 2. 유라쿠초 요코초 (Yurakucho Yokocho)
#    - 활동: 일본 각 지역의 음식을 한 곳에서 즐기는 현지 맛집 투어
#    - 팁: 저녁 시간에 방문하면 더욱 활기찬 분위기를 즐길 수 있음
#
# 2일차:
# 3. 카구라자카 (Kagurazaka)
#    - 활동: 조용한 이자카야에서 저녁 식사, 일본식 애프터눈 티 체험
#    - 팁: 등불이 켜진 거리를 산책하며 로맨틱한 분위기 만끽
#
# 4. 히칸 이나리 신사 (Hikan Inari Shrine)
#    - 활동: 아사쿠사 신사 뒤편에 위치한 초소형 신사 방문
#    - 팁: 아사쿠사 관광 중 숨겨진 명소로 들러보기 좋음
#
# 5. 오쿠노 빌딩 (Okuno Building)
#    - 활동: 긴자 중심부의 독특한 건물 투어, 공연 및 이벤트 참여
#    - 팁: 사전에 이벤트 일정 확인 필요
#
# 3일차:
# 6. 팀랩 보더리스 (teamLab Borderless)
#    - 활동: 몰입형 디지털 아트 체험
#    - 팁: 사전 예약 필수, 편한 신발과 밝은 색상의 옷 착용 추천
#
# 방문 전 필수 Tip:
# 1. 교통: IC 카드(Suica 또는 Pasmo) 구매로 편리한 대중교통 이용
# 2. 에티켓: 공공장소에서 조용히 하기, 줄 서기 예의 지키기
# 3. 결제: 현금 위주의 사회이므로 충분한 현금 준비
# 4. 언어: 기본적인 일본어 인사말 익히기
# 5. 시간 관리: 대중교통과 상점들의 정확한 운영 시간 확인
# 6. 쓰레기 처리: 쓰레기통이 적으므로 본인의 쓰레기는 숙소로 가져가기
# 7. 온천 이용 시: 문신이 있다면 사전에 허용 여부 확인
# 8. 사진 촬영: 허용되지 않는 장소에서는 삼가기
#
# 이 추천 목록은 고객의 선호도(음식, 장소, 활동)와 가중치를 고려하여 작성되었습니다. 특히 현지 음식 체험, 독특한 장소 방문, 그리고 다양한 활동을 포함하여 균형 잡힌 여행 경험을 제공합니다. 각 장소는 도쿄의 숨겨진 매력을 느낄 수 있는 곳들로, 일반적인 관광지를 넘어선 특별한 경험을 선사할 것입니다.
#
# > Finished chain.
#  [DEBUG]: == [도쿄 현지 전문가] Task output: 도쿄 추천장소 목록 및 활동 (고객 선호도와 우선순위 반영):
#
# 1일차:
# 1. 신주쿠 골든 가이 (Golden Gai)
#    - 활동: 현지인들과 어울려 독특한 분위기의 작은 바들 탐방
#    - 팁: 좁은 골목이므로 편한 신발 착용, 현금 준비 필수
#
# 2. 유라쿠초 요코초 (Yurakucho Yokocho)
#    - 활동: 일본 각 지역의 음식을 한 곳에서 즐기는 현지 맛집 투어
#    - 팁: 저녁 시간에 방문하면 더욱 활기찬 분위기를 즐길 수 있음
#
# 2일차:
# 3. 카구라자카 (Kagurazaka)
#    - 활동: 조용한 이자카야에서 저녁 식사, 일본식 애프터눈 티 체험
#    - 팁: 등불이 켜진 거리를 산책하며 로맨틱한 분위기 만끽
#
# 4. 히칸 이나리 신사 (Hikan Inari Shrine)
#    - 활동: 아사쿠사 신사 뒤편에 위치한 초소형 신사 방문
#    - 팁: 아사쿠사 관광 중 숨겨진 명소로 들러보기 좋음
#
# 5. 오쿠노 빌딩 (Okuno Building)
#    - 활동: 긴자 중심부의 독특한 건물 투어, 공연 및 이벤트 참여
#    - 팁: 사전에 이벤트 일정 확인 필요
#
# 3일차:
# 6. 팀랩 보더리스 (teamLab Borderless)
#    - 활동: 몰입형 디지털 아트 체험
#    - 팁: 사전 예약 필수, 편한 신발과 밝은 색상의 옷 착용 추천
#
# 방문 전 필수 Tip:
# 1. 교통: IC 카드(Suica 또는 Pasmo) 구매로 편리한 대중교통 이용
# 2. 에티켓: 공공장소에서 조용히 하기, 줄 서기 예의 지키기
# 3. 결제: 현금 위주의 사회이므로 충분한 현금 준비
# 4. 언어: 기본적인 일본어 인사말 익히기
# 5. 시간 관리: 대중교통과 상점들의 정확한 운영 시간 확인
# 6. 쓰레기 처리: 쓰레기통이 적으므로 본인의 쓰레기는 숙소로 가져가기
# 7. 온천 이용 시: 문신이 있다면 사전에 허용 여부 확인
# 8. 사진 촬영: 허용되지 않는 장소에서는 삼가기
#
# 이 추천 목록은 고객의 선호도(음식, 장소, 활동)와 가중치를 고려하여 작성되었습니다. 특히 현지 음식 체험, 독특한 장소 방문, 그리고 다양한 활동을 포함하여 균형 잡힌 여행 경험을 제공합니다. 각 장소는 도쿄의 숨겨진 매력을 느낄 수 있는 곳들로, 일반적인 관광지를 넘어선 특별한 경험을 선사할 것입니다.
#
#
#  [DEBUG]: == Working Agent: 일정 최적화 전문가
#
#
# > Entering new CrewAgentExecutor chain...
# Thought: 먼저 각 장소의 위치와 운영 시간, 그리고 이동 경로를 확인해야 합니다. 또한 고객의 선호도와 가중치를 고려하여 일정을 최적화해야 합니다. 각 장소에 대한 자세한 정보를 검색하여 효율적인 일정을 만들어보겠습니다.
#
# Action: duckduckgo_search
# Action Input: "도쿄 신주쿠 골든 가이 운영시간 위치"
# 죄송합니다. 제가 실수했습니다. 올바른 형식으로 다시 시도하겠습니다.
#
# Thought: 신주쿠 골든 가이의 운영 시간과 위치 정보를 확인하여 일정 계획에 반영해야 합니다.
#
# Action: duckduckgo_search
# Action Input: {"query": "도쿄 신주쿠 골든 가이 운영시간 위치"}
#
#
# 위치 Shinjuku Golden Gai(바 밀집) 2일차 (5) ... 도쿄의 제대로된 이자카야 골목을 즐기고 싶다면 신주쿠 골든가이 강.력.추.천!! ... 도쿄여행 1일차 :: 신주쿠 이자카야 꼬치골목 오모이데요코초 야키토리 맛집 ... 도달 방법: 골든가이 내에 위치, 신주쿠역에서 도보 약 7분 거리. 특별기능: 독특한 장식이 돋보이는 공포 테마의 바. 활기찬 분위기와 독창적인 음료로 유명합니다. 3. 라 제테. La Jetée는 매력적이고 아늑한 분위기로 Golden Gai에 프랑스의 감각을 더합니다. 신주쿠 골든 가이, 도쿄 야경을 무료로 볼 수 있는 도쿄도청. 그리고 칸다역 이자카야 2018 도쿄 여행 / 여행 2019. 작년에도 다녀온 도쿄 이번년도 5월에도. 특가로 다녀올 예정이에요! 히히 신주쿠 는 도쿄의 대표 번화가로 볼거리. 정말 많아서 여기저기 구경하기 좋죠. 오늘은 도쿄 신주쿠 여행했을때 볼거리. 무엇이 있는지 알차게 총정리해봤습니다. 신주쿠 골든가이를 비롯해 신주쿠의 동쪽출구, 서쪽출구, 가부키초 등 각 번화가 정리. 업데이트 날짜: 2023.10.30. JR히가시니혼 (동일본)이 발표한 데이터에 따르면 매년 가장 많은 이용객이 방문한다는 신주쿠 역. 미로같은 신주쿠 역을 나오면 가부키 초나 골든 ...
#
# Thought: 신주쿠 골든 가이에 대한 정보를 얻었습니다. 이제 다른 장소들의 정보도 수집하여 전체적인 일정을 계획해야 합니다. 유라쿠초 요코초, 카구라자카, 히칸 이나리 신사, 오쿠노 빌딩, 팀랩 보더리스의 위치와 운영 시간을 확인하겠습니다.
#
# Action: duckduckgo_search
# Action Input: {"query": "도쿄 유라쿠초 요코초 카구라자카 히칸 이나리 신사 오쿠노 빌딩 팀랩 보더리스 위치 운영시간"}
#
#
# 일본 도쿄 팀랩 보더리스 입장권 - 클룩 Klook 한국. 도쿄 모리 빌딩 디지털 아트 뮤지엄 내에 위치한 팀랩 보더리스에서는 아름다운 빛과 소리로 빚어낸 다채로운 전시 작품들을 온 몸을 이용해 감상할 수 있습니다. 지금 클룩에서 예약하세요! ... 📌 운영시간 ... 그럼 팀랩보더리스 오픈 정보에 대해 알아보실까요! 24년 도쿄 팀랩 보더리스 재오픈! 도쿄여행하면 반드시 가야 할 실내여행지로 유명했던 도쿄 팀랩 보더리스(TeamLab Borderless)가 2022년 8월부로 폐관을 했다가, 2024년 2월 중순에 새 단장을 하여 새롭게 오픈했습니다. 도쿄 여덟째 날! 고작 2주 여행한 걸 2년에 걸쳐 . 포스팅할 생각이냐 싶음 ㅎ. 그치만 너무 더워서 일하는 시간 말곤 . 컴퓨터 앞에 앉기가 너무 싫었다고오. 아무튼 다시 기억을 더듬고 더듬어서. 여덟째 날 기록 시작! 2021년 10월 교토의 유명점 'Vegan Ramen UZU'가 도쿄에 진출해 팀랩 플래닛 부지에서 문을 열었습니다. 아트작품으로 둘러싸인 공간에서 동물성 식품을 일절 사용하지 않은 비건 라면을 즐길 수 있습니다. 도쿄점 한정 메뉴도 있습니다. 교토의 'Vegan Ramen UZU Kyoto'는 ... 2024년 최신! 도쿄에 새롭게 오픈한 시설과 관광명소! 팀랩 보더리스, 도요스의 센캬쿠반라이 등 정리. 코로나가 안정세로 접어들면서 레저와 관광 을 본격적으로 즐길 수 있게 된 2023년부터 2024년까 사이에 도쿄에도 새로운 명소와 랜드마크 등 매력적인 장소가 ...
#
# Thought: 수집한 정보를 바탕으로 3일간의 여행 일정을 최적화하겠습니다. 고객의 선호도와 가중치를 고려하여 일정을 조정하고, 이동 경로와 수단을 상세히 설명하겠습니다.
#
# Final Answer:
#
# 최적화된 3일 도쿄 여행 일정:
#
# 1일차:
# - 20:00 도착 후 도세이호텔 코코네우에노 체크인
# - 21:00 - 23:00 유라쿠초 요코초 방문
#   * 이동: 우에노역에서 야마노테선 타고 유라쿠초역으로 이동 (약 20분)
#   * 활동: 현지 맛집 투어, 일본 각 지역의 음식 체험
#   * 음식점 예비 후보:
#     1. 모츠야키 센몬텐 오레노 (호르몬 요리)
#     2. 야키토리 도리큐 (꼬치구이)
#     3. 이자카야 앤도 (해산물 요리)
#
# 2일차:
# - 09:00 - 11:00 히칸 이나리 신사 방문
#   * 이동: 호텔에서 긴자선 타고 아사쿠사역으로 이동 (약 30분)
#   * 활동: 아사쿠사 관광과 함께 숨겨진 명소 탐방
# - 12:00 - 14:00 점심 및 이동
#   * 점심 예비 후보:
#     1. 후지소바 (소바 전문점)
#     2. 나미키야 (덮밥 전문점)
#     3. 센소지 템플 카페 (일본식 카페)
# - 14:30 - 16:30 오쿠노 빌딩 투어
#   * 이동: 아사쿠사에서 긴자선 타고 긴자역으로 이동 (약 15분)
#   * 활동: 독특한 건물 투어, 가능한 경우 공연 또는 이벤트 참여
# - 17:00 Nippon Seinenkan Hotel Tokyo, Shinjuku 체크인
# - 18:30 - 21:30 카구라자카 방문
#   * 이동: 호텔에서 도보로 이동 (약 15분)
#   * 활동: 조용한 이자카야에서 저녁 식사, 일본식 애프터눈 티 체험
#   * 저녁 예비 후보:
#     1. 카구라 (고급 일본 요리)
#     2. 비스트로 카구라 (프랑스-일본 퓨전)
#     3. 토리잔마이 (닭요리 전문점)
#
# 3일차:
# - 10:00 - 14:00 팀랩 보더리스 방문
#   * 이동: 호텔에서 오에도선 타고 아오미역으로 이동 (약 40분)
#   * 활동: 몰입형 디지털 아트 체험 (사전 예약 필수)
# - 15:00 - 17:00 점심 및 휴식
#   * 점심 예비 후보:
#     1. 스시 잔마이 (스시)
#     2. 고토부키 (텐푸라)
#     3. 우나기 시라카와 (장어 요리)
# - 18:00 - 22:00 신주쿠 골든 가이 방문
#   * 이동: 호텔에서 도보로 이동 (약 10분)
#   * 활동: 현지인들과 어울려 독특한 분위기의 작은 바들 탐방
#   * 저녁 예비 후보:
#     1. 오모이데 요코초 (야키토리)
#     2. 골든 가이 앨리 (이자카야)
#     3. 라 제테 (프랑스-일본 퓨전 바)
#
# 22:00 출발
#
# 이 일정은 고객의 선호도와 가중치를 반영하여 최적화되었습니다. 음식(25%)과 장소(30%)에 높은 가중치를 두어 다양한 일본 음식을 체험하고 독특한 장소들을 방문하는 데 중점을 두었습니다. 또한 활동(20%)에도 적절한 시간을 할당하여 균형 잡힌 여행 경험을 제공합니다.
#
# 각 장소 간 이동은 주로 도쿄의 효율적인 대중교통 시스템을 이용하며, 가까운 거리는 도보로 이동하여 현지 분위기를 느낄 수 있도록 했습니다. IC 카드(Suica 또는 Pasmo)를 구매하여 편리하게 대중교통을 이용하시기 바랍니다.
#
# 음식점은 각 끼니별로 다양한 일본 요리를 체험할 수 있는 예비 후보지를 제안했습니다. 현지 상황에 따라 선택하실 수 있습니다.
#
# 마지막으로, 앞서 제공된 방문 전 필수 팁을 꼭 참고하시어 즐겁고 편안한 여행이 되시기를 바랍니다.
#
# > Finished chain.
#  [DEBUG]: == [일정 최적화 전문가] Task output: 최적화된 3일 도쿄 여행 일정:
#
# 1일차:
# - 20:00 도착 후 도세이호텔 코코네우에노 체크인
# - 21:00 - 23:00 유라쿠초 요코초 방문
#   * 이동: 우에노역에서 야마노테선 타고 유라쿠초역으로 이동 (약 20분)
#   * 활동: 현지 맛집 투어, 일본 각 지역의 음식 체험
#   * 음식점 예비 후보:
#     1. 모츠야키 센몬텐 오레노 (호르몬 요리)
#     2. 야키토리 도리큐 (꼬치구이)
#     3. 이자카야 앤도 (해산물 요리)
#
# 2일차:
# - 09:00 - 11:00 히칸 이나리 신사 방문
#   * 이동: 호텔에서 긴자선 타고 아사쿠사역으로 이동 (약 30분)
#   * 활동: 아사쿠사 관광과 함께 숨겨진 명소 탐방
# - 12:00 - 14:00 점심 및 이동
#   * 점심 예비 후보:
#     1. 후지소바 (소바 전문점)
#     2. 나미키야 (덮밥 전문점)
#     3. 센소지 템플 카페 (일본식 카페)
# - 14:30 - 16:30 오쿠노 빌딩 투어
#   * 이동: 아사쿠사에서 긴자선 타고 긴자역으로 이동 (약 15분)
#   * 활동: 독특한 건물 투어, 가능한 경우 공연 또는 이벤트 참여
# - 17:00 Nippon Seinenkan Hotel Tokyo, Shinjuku 체크인
# - 18:30 - 21:30 카구라자카 방문
#   * 이동: 호텔에서 도보로 이동 (약 15분)
#   * 활동: 조용한 이자카야에서 저녁 식사, 일본식 애프터눈 티 체험
#   * 저녁 예비 후보:
#     1. 카구라 (고급 일본 요리)
#     2. 비스트로 카구라 (프랑스-일본 퓨전)
#     3. 토리잔마이 (닭요리 전문점)
#
# 3일차:
# - 10:00 - 14:00 팀랩 보더리스 방문
#   * 이동: 호텔에서 오에도선 타고 아오미역으로 이동 (약 40분)
#   * 활동: 몰입형 디지털 아트 체험 (사전 예약 필수)
# - 15:00 - 17:00 점심 및 휴식
#   * 점심 예비 후보:
#     1. 스시 잔마이 (스시)
#     2. 고토부키 (텐푸라)
#     3. 우나기 시라카와 (장어 요리)
# - 18:00 - 22:00 신주쿠 골든 가이 방문
#   * 이동: 호텔에서 도보로 이동 (약 10분)
#   * 활동: 현지인들과 어울려 독특한 분위기의 작은 바들 탐방
#   * 저녁 예비 후보:
#     1. 오모이데 요코초 (야키토리)
#     2. 골든 가이 앨리 (이자카야)
#     3. 라 제테 (프랑스-일본 퓨전 바)
#
# 22:00 출발
#
# 이 일정은 고객의 선호도와 가중치를 반영하여 최적화되었습니다. 음식(25%)과 장소(30%)에 높은 가중치를 두어 다양한 일본 음식을 체험하고 독특한 장소들을 방문하는 데 중점을 두었습니다. 또한 활동(20%)에도 적절한 시간을 할당하여 균형 잡힌 여행 경험을 제공합니다.
#
# 각 장소 간 이동은 주로 도쿄의 효율적인 대중교통 시스템을 이용하며, 가까운 거리는 도보로 이동하여 현지 분위기를 느낄 수 있도록 했습니다. IC 카드(Suica 또는 Pasmo)를 구매하여 편리하게 대중교통을 이용하시기 바랍니다.
#
# 음식점은 각 끼니별로 다양한 일본 요리를 체험할 수 있는 예비 후보지를 제안했습니다. 현지 상황에 따라 선택하실 수 있습니다.
#
# 마지막으로, 앞서 제공된 방문 전 필수 팁을 꼭 참고하시어 즐겁고 편안한 여행이 되시기를 바랍니다.
#
#
# 최종 여행 계획:
# 최적화된 3일 도쿄 여행 일정:
#
# 1일차:
# - 20:00 도착 후 도세이호텔 코코네우에노 체크인
# - 21:00 - 23:00 유라쿠초 요코초 방문
#   * 이동: 우에노역에서 야마노테선 타고 유라쿠초역으로 이동 (약 20분)
#   * 활동: 현지 맛집 투어, 일본 각 지역의 음식 체험
#   * 음식점 예비 후보:
#     1. 모츠야키 센몬텐 오레노 (호르몬 요리)
#     2. 야키토리 도리큐 (꼬치구이)
#     3. 이자카야 앤도 (해산물 요리)
#
# 2일차:
# - 09:00 - 11:00 히칸 이나리 신사 방문
#   * 이동: 호텔에서 긴자선 타고 아사쿠사역으로 이동 (약 30분)
#   * 활동: 아사쿠사 관광과 함께 숨겨진 명소 탐방
# - 12:00 - 14:00 점심 및 이동
#   * 점심 예비 후보:
#     1. 후지소바 (소바 전문점)
#     2. 나미키야 (덮밥 전문점)
#     3. 센소지 템플 카페 (일본식 카페)
# - 14:30 - 16:30 오쿠노 빌딩 투어
#   * 이동: 아사쿠사에서 긴자선 타고 긴자역으로 이동 (약 15분)
#   * 활동: 독특한 건물 투어, 가능한 경우 공연 또는 이벤트 참여
# - 17:00 Nippon Seinenkan Hotel Tokyo, Shinjuku 체크인
# - 18:30 - 21:30 카구라자카 방문
#   * 이동: 호텔에서 도보로 이동 (약 15분)
#   * 활동: 조용한 이자카야에서 저녁 식사, 일본식 애프터눈 티 체험
#   * 저녁 예비 후보:
#     1. 카구라 (고급 일본 요리)
#     2. 비스트로 카구라 (프랑스-일본 퓨전)
#     3. 토리잔마이 (닭요리 전문점)
#
# 3일차:
# - 10:00 - 14:00 팀랩 보더리스 방문
#   * 이동: 호텔에서 오에도선 타고 아오미역으로 이동 (약 40분)
#   * 활동: 몰입형 디지털 아트 체험 (사전 예약 필수)
# - 15:00 - 17:00 점심 및 휴식
#   * 점심 예비 후보:
#     1. 스시 잔마이 (스시)
#     2. 고토부키 (텐푸라)
#     3. 우나기 시라카와 (장어 요리)
# - 18:00 - 22:00 신주쿠 골든 가이 방문
#   * 이동: 호텔에서 도보로 이동 (약 10분)
#   * 활동: 현지인들과 어울려 독특한 분위기의 작은 바들 탐방
#   * 저녁 예비 후보:
#     1. 오모이데 요코초 (야키토리)
#     2. 골든 가이 앨리 (이자카야)
#     3. 라 제테 (프랑스-일본 퓨전 바)
#
# 22:00 출발
#
# 이 일정은 고객의 선호도와 가중치를 반영하여 최적화되었습니다. 음식(25%)과 장소(30%)에 높은 가중치를 두어 다양한 일본 음식을 체험하고 독특한 장소들을 방문하는 데 중점을 두었습니다. 또한 활동(20%)에도 적절한 시간을 할당하여 균형 잡힌 여행 경험을 제공합니다.
#
# 각 장소 간 이동은 주로 도쿄의 효율적인 대중교통 시스템을 이용하며, 가까운 거리는 도보로 이동하여 현지 분위기를 느낄 수 있도록 했습니다. IC 카드(Suica 또는 Pasmo)를 구매하여 편리하게 대중교통을 이용하시기 바랍니다.
#
# 음식점은 각 끼니별로 다양한 일본 요리를 체험할 수 있는 예비 후보지를 제안했습니다. 현지 상황에 따라 선택하실 수 있습니다.
#
# 마지막으로, 앞서 제공된 방문 전 필수 팁을 꼭 참고하시어 즐겁고 편안한 여행이 되시기를 바랍니다.

# %%
from crewai import Agent, Task, Crew
from langchain_openai import ChatOpenAI
from langchain.tools import DuckDuckGoSearchRun
from langchain_anthropic import ChatAnthropic
from langchain.agents import Tool
from dotenv import load_dotenv
import os

load_dotenv()

gpt = ChatOpenAI(model="gpt-4o-mini",
             api_key=os.getenv("OPENAI_API_KEY"), 
             temperature=0,
             max_tokens=4000)

clud = ChatAnthropic(model="claude-3-5-sonnet-20240620",
                     anthropic_api_key=os.getenv("Anthropic_API_KEY"),
                     temperature=0,
                     max_tokens=4000)

# 도구 초기화
search_tool = DuckDuckGoSearchRun()

# 검색 도구 래퍼 함수
def search_wrapper(query):
    # 여기에서 쿼리 전처리나 로깅을 수행할 수 있습니다
    print(f"Performing search with query: {query}")
    return search_tool.run(query)

# 에이전트 정의
travel_planner = Agent(
    role='여행 계획가',
    goal='고객의 선호도와 예산에 맞는 최적의 여행 계획 수립',
    backstory='15년 경력의 전문 여행 계획가로, 다양한 고객의 요구사항을 만족시키는 맞춤형 여행 계획을 수립합니다.',
    verbose=True,
    allow_delegation=False,
    tools=[Tool(
        name="Search",
        func=search_wrapper,
        description="유용한 정보를 검색하는 도구"
    )],
    llm=gpt
)

local_expert = Agent(
    role='도쿄 현지 전문가',
    goal='도쿄의 숨겨진 명소와 현지 문화에 대한 깊이 있는 정보 제공',
    backstory='도쿄에서 10년 이상 거주한 현지 전문가로, 관광객들이 쉽게 접하기 어려운 특별한 경험을 제안합니다.',
    verbose=True,
    allow_delegation=False,
    tools=[Tool(
        name="Search",
        func=search_wrapper,
        description="유용한 정보를 검색하는 도구"
    )],
    llm=clud
)

schedule_optimizer = Agent(
    role='일정 최적화 전문가',
    goal='효율적이고 즐거운 3일 도쿄 여행 일정 최적화',
    backstory='데이터 분석과 여행 경험을 결합하여 고객의 시간과 에너지를 최대한 활용할 수 있는 최적의 일정을 설계합니다.',
    verbose=True,
    allow_delegation=False,
    tools=[Tool(
        name="Search",
        func=search_wrapper,
        description="유용한 정보를 검색하는 도구"
    )],
    llm=clud
)

# 나머지 코드는 동일하게 유지...

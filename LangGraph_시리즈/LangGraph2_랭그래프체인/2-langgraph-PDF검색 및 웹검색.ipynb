# %% [markdown]
# # 부족한 정보를 검색하여 Context 보강
#
# **절차**
#
# 1. 전통적인 RAG 를 수행
# 2. 검색된 문서에 답변에 필요한 정보가 부족한 경우 -> “웹 검색”을 위한 쿼리 재작성
# 3. “웹 검색” 으로 보충된 정보로 답변 도출 시도
# 4. 새로운 답변으로 관련성 체크 후 재조정/종료 진행

# %%
# api key
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install -qU langchain-teddynote
from easy_langsmith import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("CH17-LANGGRAPH")
# Out:
# LangSmith logging start
# [Project]
# CH17-LANGGRAPH

# %%
from rag.pdf import PDFRetrievalChain

pdf = PDFRetrievalChain(["data/글로벌 음악 산업의 해자가 될, Superfans BM .pdf"]).create_chain()
pdf_retriever = pdf.retriever
pdf_chain = pdf.chain

# %% [markdown]
# ## GraphState
#
# 각 노드에서 다음 노드로 전달되는 상태를 저장합니다.

# %%
from typing import TypedDict

# GraphState 상태를 저장하는 용도로 사용합니다.
class GraphState(TypedDict):
    question: str  # 질문
    context: str  # 문서의 검색 결과
    answer: str  # 답변
    relevance: str  # 답변의 문서에 대한 관련성

# %% [markdown]
# ## 노드와 엣지
#
# 우리는 agentic RAG 그래프를 다음과 같이 구성할 수 있습니다:
#
# - 상태는 메시지의 집합입니다
# - 각 노드는 상태를 업데이트(추가)합니다
# - 조건부 엣지는 다음에 방문할 노드를 결정합니다
#
# ![](https://teddylee777.github.io/images/2024-03-06-langgraph-agentic-rag/nodes-and-edges.png)

# %%
from langchain_upstage import UpstageGroundednessCheck
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_community.tools.tavily_search import TavilySearchResults
import os
from rag.utils import format_docs, format_searched_docs
# 업스테이지 문서 관련성 체크 기능을 설정합니다. https://upstage.ai
upstage_ground_checker = UpstageGroundednessCheck(api_key=os.getenv("UPSTAGE_API_KEY", "default_value"))

# 문서에서 검색하여 관련성 있는 문서를 찾습니다.
def retrieve_document(state: GraphState) -> GraphState:
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    retrieved_docs = pdf_retriever.invoke(state["question"])

    # 검색된 문서를 형식화합니다.
    retrieved_docs = format_docs(retrieved_docs)

    # 검색된 문서를 context 키에 저장합니다.
    return GraphState(context=retrieved_docs)


# LLM을 사용하여 답변을 생성합니다.
def llm_answer(state: GraphState) -> GraphState:
    question = state["question"]
    context = state["context"]

    # 체인을 호출하여 답변을 생성합니다.
    response = pdf_chain.invoke({"question": question, "context": context})

    return GraphState(answer=response)


def rewrite(state):
    question = state["question"]
    answer = state["answer"]
    context = state["context"]
    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "You are a professional prompt rewriter. Your task is to generate the question in order to get additional information that is now shown in the context."
                "Your generated question will be searched on the web to find relevant information.",
            ),
            (
                "human",
                "Rewrite the question to get additional information to get the answer."
                "\n\nHere is the initial question:\n ------- \n{question}\n ------- \n"
                "\n\nHere is the initial context:\n ------- \n{context}\n ------- \n"
                "\n\nHere is the initial answer to the question:\n ------- \n{answer}\n ------- \n"
                "\n\nFormulate an improved question in Korean:",
            ),
        ]
    )

    # Question rewriting model
    model = ChatOpenAI(temperature=0, model="gpt-4o-mini")

    chain = prompt | model | StrOutputParser()
    response = chain.invoke(
        {"question": question, "answer": answer, "context": context}
    )
    return GraphState(question=response)


def search_on_web(state: GraphState) -> GraphState:
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    search_tool = TavilySearchResults(max_results=5)
    search_result = search_tool.invoke({"query": state["question"]})

    # 검색된 문서를 형식화합니다.
    search_result = format_searched_docs(search_result)
    # 검색된 문서를 context 키에 저장합니다.
    return GraphState(
        context=search_result,
    )


def relevance_check(state: GraphState) -> GraphState:
    print("relevance_check", state)
    # 관련성 체크를 실행합니다. 결과: grounded, notGrounded, notSure
    response = upstage_ground_checker.run(
        {"context": state["context"], "answer": state["answer"]}
    )
    return GraphState(
        relevance=response, question=state["question"], answer=state["answer"]
    )


def is_relevant(state: GraphState) -> GraphState:
    return state["relevance"]

# %%
from langgraph.graph import END, StateGraph
from langgraph.checkpoint.memory import MemorySaver

# langgraph.graph에서 StateGraph와 END를 가져옵니다.
workflow = StateGraph(GraphState)

# 노드들을 정의합니다.
workflow.add_node("retrieve", retrieve_document)  # 에이전트 노드를 추가합니다.
workflow.add_node("llm_answer", llm_answer)  # 정보 검색 노드를 추가합니다.
workflow.add_node(
    "relevance_check", relevance_check
)  # 답변의 문서에 대한 관련성 체크 노드를 추가합니다.
workflow.add_node("rewrite", rewrite)  # 질문을 재작성하는 노드를 추가합니다.
workflow.add_node("search_on_web", search_on_web)  # 웹 검색 노드를 추가합니다.

# 각 노드들을 연결합니다.
workflow.add_edge("retrieve", "llm_answer")  # 검색 -> 답변
workflow.add_edge("llm_answer", "relevance_check")  # 답변 -> 관련성 체크
workflow.add_edge("rewrite", "search_on_web")  # 재작성 -> 관련성 체크
workflow.add_edge("search_on_web", "llm_answer")  # 웹 검색 -> 답변


# 조건부 엣지를 추가합니다.
workflow.add_conditional_edges(
    "relevance_check",  # 관련성 체크 노드에서 나온 결과를 is_relevant 함수에 전달합니다.
    is_relevant,
    {
        "grounded": END,  # 관련성이 있으면 종료합니다.
        "notGrounded": "rewrite",  # 관련성이 없으면 다시 답변을 생성합니다.
        "notSure": "rewrite",  # 관련성 체크 결과가 모호하다면 다시 답변을 생성합니다.
    },
)


workflow.set_entry_point("retrieve")

memory = MemorySaver()

app = workflow.compile(checkpointer=memory)

# %%
from IPython.display import Image, display

try:
    display(
        Image(app.get_graph(xray=True).draw_mermaid_png())
    )  # 실행 가능한 객체의 그래프를 mermaid 형식의 PNG로 그려서 표시합니다. xray=True는 추가적인 세부 정보를 포함합니다.
except:
    # 이 부분은 추가적인 의존성이 필요하며 선택적으로 실행됩니다.
    pass

# %%
import pprint
from langgraph.errors import GraphRecursionError
from langchain_core.runnables import RunnableConfig
from rag.utils import format_task

config = RunnableConfig(
    recursion_limit=12, configurable={"thread_id": "CORRECTIVE-SEARCH-RAG"}
)

# AgentState 객체를 활용하여 질문을 입력합니다.
inputs = GraphState(
    question="superfans BM을 어떻게 준비해야돼?"
)

# app.stream을 통해 입력된 메시지에 대한 출력을 스트리밍합니다.
try:
    for output in app.stream(inputs, config=config):
        # 출력된 결과에서 키와 값을 순회합니다.
        for key, value in output.items():
            # 노드의 이름과 해당 노드에서 나온 출력을 출력합니다.
            pprint.pprint(f"Output from node '{key}':")
            pprint.pprint("---")
            # 출력 값을 예쁘게 출력합니다.
            pprint.pprint(value, indent=2, width=80, depth=None)
        # 각 출력 사이에 구분선을 추가합니다.
        pprint.pprint("\n---\n")
except GraphRecursionError as e:
    pprint.pprint(f"Recursion limit reached: {e}")
# Out:
# "Output from node 'retrieve':"
# '---'
# { 'context': '<document><content>엔터(Positive)| 한화 월간 엔터 Sep, ’24: 글로벌 음악 산업의 '
#              '해자가 될, Sueperfans BM [한화리서치]\n'
#              '>> 글로벌 음악 산업의 해자가 될, Sueperfans BM\n'
#              '지난 4월에 이 개념을 주제로 in-depth 자료를 작성하기도 했는데, 미국 음악 시장 소\n'
#              '비자 가운데 약 20%가 Superfans(fans that engage with artists and their '
#              'contents in 5+\n'
#              'different ways -Luminate)로 분류되며, 일반적인 소비자들보다 약 2배에 가까운 지출\n'
#              '성향을 보이며 산업에서 "중요한 존재"로 떠오르고 있다. 뿐만 아니라, 경험을 SNS상(인\n'
#              '스타그램/틱톡 등)에 공유하는 문화 덕에 경험 소비 지출 성향이 커지고 있어 향후 음\n'
#              '악 시장에서 superfans의 비중이나 그들의 지출 규모가 더 커질 것으로 예상된다. 때문\n'
#              '인지 글로벌 음악 시장 주요 플레이어인 UMG나 WMG의 미래 성장과 관련된 '
#              '이야기</content><source>data/글로벌 음악 산업의 해자가 될, Superfans BM '
#              '.pdf</source><page>2</page></document>\n'
#              '<document><content>2 3 /0\n'
#              'B\n'
#              '2 3 /0\n'
#              '7\n'
#              'P\n'
#              '7\n'
#              'N\n'
#              'K\n'
#              'C T\n'
#              '2\n'
#              '2\n'
#              'D R\n'
#              '3 /1\n'
#              '3 /1\n'
#              'E\n'
#              '0\n'
#              '0\n'
#              'A\n'
#              'T\n'
#              'M\n'
#              'R\n'
#              '2\n'
#              'S\n'
#              '2\n'
#              '4\n'
#              '4\n'
#              'R E\n'
#              '/0 1\n'
#              '/0 1\n'
#              'V A S\n'
#              '2 4 /0\n'
#              'B B M\n'
#              '2 4 /0\n'
#              'P\n'
#              '4\n'
#              '4\n'
#              'R\n'
#              '2\n'
#              '2\n'
#              'IZ\n'
#              '4 /0\n'
#              '4 /0\n'
#              '7\n'
#              '7</content><source>data/글로벌 음악 산업의 해자가 될, Superfans BM '
#              '.pdf</source><page>4</page></document>\n'
#              '<document><content>랫폼 사업자와의 협력이나 신규 플랫폼 출시를 노력 중이다.\n'
#              '이런 업계 분위기 속에서, 최근에는 영국 기반의 <FanCircles>라는 팬덤 플랫폼이 큰\n'
#              '규모는 아니나, 200만달러의 투자 유치 소식을 전하기도 했다. 이 플랫폼은 아티스트가\n'
#              '자신만의 맞춤형 애플리케이션을 통해 팬들과 소통하는 기능을 제공한다. 서비스 중인\n'
#              '대표 아티스트로는 로비 윌리엄스(Robbie Williams)가 있다. 연 구독료 99달러로 독점\n'
#              '콘텐츠 제공/라이브 스트리밍/상품 판매 등을 제공해 superfans monetization을 실현한\n'
#              '다. 이런 D2C 팬덤 플랫폼 외에도 차별화된 콘서트 티켓 판매 플랫폼을 운영하는 스타\n'
#              '트업들이 최근 업계에서 각광받는다. Dice, Eventbrite. Lyte처럼 VIP 전용 티켓(특별 좌\n'
#              '석 구매, 사전 입장 및 리허설 관람, 독점 콘텐츠 제공)을 판매하거나 이용자 간 재판매\n'
#              '서비스를 제공하는 플랫폼 사업자들이 대표적이다.</content><source>data/글로벌 음악 산업의 해자가 '
#              '될, Superfans BM .pdf</source><page>2</page></document>\n'
#              '<document><content>있다. 전반적인 소비 트렌드 자체가 소비층 내 superfans 비중 확대 및\n'
#              '이슈화되는 주제들에 대한 코멘트를 함께\n'
#              'superfans 소비 성향 확대로 이어지고 있는 탓에 “superfans monetization”을\n'
#              '담고 있습니다.\n'
#              '위한 D2C 플랫폼의 역할이 부각되고 있다. 그런데 그들이 이야기하는\n'
#              'superfans는 결국 K-Pop의 빠순이/오타쿠(코어 팬덤)와 유사하다. 해외 플레\n'
#              '이어들이 강조하는 “superfans monetization”은 수십년간 K-Pop 산업의 헤게\n'
#              '모니로 자리잡고 있다. 즉, 수익화 방법론 관점에서 보자면, UMG나 WMG\n'
#              '와 같은 글로벌 주요 플레이어들 보다도 우위에 있다. K-Pop 플레이어들이\n'
#              '돈을 벌어온 방식, 산업이 성장해온 방식이 최근의 소비 트렌드와 가장 잘 맞\n'
#              '닿아 있다. “산업의 경제적 해자가 될 superfans BM 선점”으로 봐도 될텐데,\n'
#              '여러 노이즈나 실적 부진 탓에 다소 피상적으로 들린다. 그러나 노이즈가 '
#              '해</content><source>data/글로벌 음악 산업의 해자가 될, Superfans BM '
#              '.pdf</source><page>1</page></document>\n'
#              '<document><content>여러 노이즈나 실적 부진 탓에 다소 피상적으로 들린다. 그러나 노이즈가 해\n'
#              '소되고 실적이 반등하는 시점에는 멀티플 프리미엄 부여의 가장 강력한 요소\n'
#              '가 될 수 있다. 4분기 중 위버스 멤버십 플러스가 공개된다. “구독료 얼마, 몇\n'
#              '팀 출시, 구독 전환율 얼마”와 같은 단기적인 숫자도 물론 중요하지만, 장기적\n'
#              '인 확장성까지 그려 보길 투자자들에게 권하는 이유다.\n'
#              '8월 음반 판매량 Update\n'
#              '8월에는 르세라핌, 엔믹스, 재현을 제외하면 주요 4사 앨범 발매 이벤트가 많\n'
#              '지 않았다. Circle Chart 기준 전체 518만장을 기록했으며, 4사 합산 판매량은\n'
#              '157만장에 불과했다. Big IP의 발매 부재로 판매량 및 수출 data 모두 부진할\n'
#              '수밖에 없는 달이었다. 9월에도 주요 발매 라인업으로 선주문 81만장을 기록\n'
#              '한 보이넥스트도어, 데뷔 1주년을 맞이한 라이즈의 에필로그 앨범, 쯔위의 솔\n'
#              '로 앨범 정도가 전부라 다소 밋밋한 판매량이 예상된다. 그러나 2분기 '
#              '컴백했</content><source>data/글로벌 음악 산업의 해자가 될, Superfans BM '
#              '.pdf</source><page>1</page></document>'}
# '\n---\n'
# "Output from node 'llm_answer':"
# '---'
# { 'answer': '주어진 문맥에서 Superfans BM을 준비하는 구체적인 방법에 대한 정보는 제공되지 않습니다. 다만, '
#             'Superfans BM이 글로벌 음악 시장에서 중요한 역할을 하고 있으며, superfans가 아티스트와 그들의 '
#             '콘텐츠에 다양한 방식으로 참여함으로써 산업에 큰 영향을 미치고 있다는 일반적인 정보만 언급되어 있습니다. 따라서 '
#             'Superfans BM을 준비하는 구체적인 방법에 대한 정보는 "주어진 정보에서 질문에 대한 정보를 찾을 수 '
#             '없습니다"라고 답해야 합니다.'}
# '\n---\n'
# relevance_check {'question': 'superfans BM을 어떻게 준비해야돼?', 'context': '<document><content>엔터(Positive)| 한화 월간 엔터 Sep, ’24: 글로벌 음악 산업의 해자가 될, Sueperfans BM [한화리서치]\n>> 글로벌 음악 산업의 해자가 될, Sueperfans BM\n지난 4월에 이 개념을 주제로 in-depth 자료를 작성하기도 했는데, 미국 음악 시장 소\n비자 가운데 약 20%가 Superfans(fans that engage with artists and their contents in 5+\ndifferent ways -Luminate)로 분류되며, 일반적인 소비자들보다 약 2배에 가까운 지출\n성향을 보이며 산업에서 "중요한 존재"로 떠오르고 있다. 뿐만 아니라, 경험을 SNS상(인\n스타그램/틱톡 등)에 공유하는 문화 덕에 경험 소비 지출 성향이 커지고 있어 향후 음\n악 시장에서 superfans의 비중이나 그들의 지출 규모가 더 커질 것으로 예상된다. 때문\n인지 글로벌 음악 시장 주요 플레이어인 UMG나 WMG의 미래 성장과 관련된 이야기</content><source>data/글로벌 음악 산업의 해자가 될, Superfans BM .pdf</source><page>2</page></document>\n<document><content>2 3 /0\nB\n2 3 /0\n7\nP\n7\nN\nK\nC T\n2\n2\nD R\n3 /1\n3 /1\nE\n0\n0\nA\nT\nM\nR\n2\nS\n2\n4\n4\nR E\n/0 1\n/0 1\nV A S\n2 4 /0\nB B M\n2 4 /0\nP\n4\n4\nR\n2\n2\nIZ\n4 /0\n4 /0\n7\n7</content><source>data/글로벌 음악 산업의 해자가 될, Superfans BM .pdf</source><page>4</page></document>\n<document><content>랫폼 사업자와의 협력이나 신규 플랫폼 출시를 노력 중이다.\n이런 업계 분위기 속에서, 최근에는 영국 기반의 <FanCircles>라는 팬덤 플랫폼이 큰\n규모는 아니나, 200만달러의 투자 유치 소식을 전하기도 했다. 이 플랫폼은 아티스트가\n자신만의 맞춤형 애플리케이션을 통해 팬들과 소통하는 기능을 제공한다. 서비스 중인\n대표 아티스트로는 로비 윌리엄스(Robbie Williams)가 있다. 연 구독료 99달러로 독점\n콘텐츠 제공/라이브 스트리밍/상품 판매 등을 제공해 superfans monetization을 실현한\n다. 이런 D2C 팬덤 플랫폼 외에도 차별화된 콘서트 티켓 판매 플랫폼을 운영하는 스타\n트업들이 최근 업계에서 각광받는다. Dice, Eventbrite. Lyte처럼 VIP 전용 티켓(특별 좌\n석 구매, 사전 입장 및 리허설 관람, 독점 콘텐츠 제공)을 판매하거나 이용자 간 재판매\n서비스를 제공하는 플랫폼 사업자들이 대표적이다.</content><source>data/글로벌 음악 산업의 해자가 될, Superfans BM .pdf</source><page>2</page></document>\n<document><content>있다. 전반적인 소비 트렌드 자체가 소비층 내 superfans 비중 확대 및\n이슈화되는 주제들에 대한 코멘트를 함께\nsuperfans 소비 성향 확대로 이어지고 있는 탓에 “superfans monetization”을\n담고 있습니다.\n위한 D2C 플랫폼의 역할이 부각되고 있다. 그런데 그들이 이야기하는\nsuperfans는 결국 K-Pop의 빠순이/오타쿠(코어 팬덤)와 유사하다. 해외 플레\n이어들이 강조하는 “superfans monetization”은 수십년간 K-Pop 산업의 헤게\n모니로 자리잡고 있다. 즉, 수익화 방법론 관점에서 보자면, UMG나 WMG\n와 같은 글로벌 주요 플레이어들 보다도 우위에 있다. K-Pop 플레이어들이\n돈을 벌어온 방식, 산업이 성장해온 방식이 최근의 소비 트렌드와 가장 잘 맞\n닿아 있다. “산업의 경제적 해자가 될 superfans BM 선점”으로 봐도 될텐데,\n여러 노이즈나 실적 부진 탓에 다소 피상적으로 들린다. 그러나 노이즈가 해</content><source>data/글로벌 음악 산업의 해자가 될, Superfans BM .pdf</source><page>1</page></document>\n<document><content>여러 노이즈나 실적 부진 탓에 다소 피상적으로 들린다. 그러나 노이즈가 해\n소되고 실적이 반등하는 시점에는 멀티플 프리미엄 부여의 가장 강력한 요소\n가 될 수 있다. 4분기 중 위버스 멤버십 플러스가 공개된다. “구독료 얼마, 몇\n팀 출시, 구독 전환율 얼마”와 같은 단기적인 숫자도 물론 중요하지만, 장기적\n인 확장성까지 그려 보길 투자자들에게 권하는 이유다.\n8월 음반 판매량 Update\n8월에는 르세라핌, 엔믹스, 재현을 제외하면 주요 4사 앨범 발매 이벤트가 많\n지 않았다. Circle Chart 기준 전체 518만장을 기록했으며, 4사 합산 판매량은\n157만장에 불과했다. Big IP의 발매 부재로 판매량 및 수출 data 모두 부진할\n수밖에 없는 달이었다. 9월에도 주요 발매 라인업으로 선주문 81만장을 기록\n한 보이넥스트도어, 데뷔 1주년을 맞이한 라이즈의 에필로그 앨범, 쯔위의 솔\n로 앨범 정도가 전부라 다소 밋밋한 판매량이 예상된다. 그러나 2분기 컴백했</content><source>data/글로벌 음악 산업의 해자가 될, Superfans BM .pdf</source><page>1</page></document>', 'answer': '주어진 문맥에서 Superfans BM을 준비하는 구체적인 방법에 대한 정보는 제공되지 않습니다. 다만, Superfans BM이 글로벌 음악 시장에서 중요한 역할을 하고 있으며, superfans가 아티스트와 그들의 콘텐츠에 다양한 방식으로 참여함으로써 산업에 큰 영향을 미치고 있다는 일반적인 정보만 언급되어 있습니다. 따라서 Superfans BM을 준비하는 구체적인 방법에 대한 정보는 "주어진 정보에서 질문에 대한 정보를 찾을 수 없습니다"라고 답해야 합니다.', 'relevance': 'grounded'}
# "Output from node 'relevance_check':"
# '---'
# { 'answer': '주어진 문맥에서 Superfans BM을 준비하는 구체적인 방법에 대한 정보는 제공되지 않습니다. 다만, '
#             'Superfans BM이 글로벌 음악 시장에서 중요한 역할을 하고 있으며, superfans가 아티스트와 그들의 '
#             '콘텐츠에 다양한 방식으로 참여함으로써 산업에 큰 영향을 미치고 있다는 일반적인 정보만 언급되어 있습니다. 따라서 '
#             'Superfans BM을 준비하는 구체적인 방법에 대한 정보는 "주어진 정보에서 질문에 대한 정보를 찾을 수 '
#             '없습니다"라고 답해야 합니다.',
#   'question': 'superfans BM을 어떻게 준비해야돼?',
#   'relevance': 'notGrounded'}
# '\n---\n'
# "Output from node 'rewrite':"
# '---'
# {'question': 'Superfans BM을 준비하기 위해 필요한 구체적인 전략이나 방법론은 무엇인가요?'}
# '\n---\n'
# "Output from node 'search_on_web':"
# '---'
# { 'context': "<document><content>글로벌 음악 산업의 해자가 될, Superfans BM 월간 엔터 Sep, '24 "
#              'Analyst 박수영 3772-7634 suyoung.park.0202@hanwha.com 해외 음악 산업 '
#              '플레이어들의 최근 가장 큰 관심사는 "Superfans BM"을 어떻게 구축할 것인가 입니다. 오랜 기간 산업의 '
#              '헤게모니가 코어 팬덤 생성 및 '
#              '수익화였</content><source>https://www.bondweb.co.kr/_research/downloadPage.asp?number=797290&gn=1</source></document>\n'
#              '<document><content>BM을 구축하는 데 가장 많이 쓰이는 도구가 바로 비즈니스 모델 '
#              '캔버스(Business Model Canvas) ... 앞서 언급된 다섯 가지(CS, VP, CH, CR, R$)를 '
#              '실현하기 위해 필요한 자원을 정의합니다. 주로 활용되는 자원으로는 물리적, 재무적, 지적, 인적 자원 측면에서 '
#              '설정할 수 있고 '
#              '...</content><source>https://ggumttakji.tistory.com/13</source></document>\n'
#              '<document><content>또한 웅진이 사업 추진을 위해 필요한 침대회사와의 제휴 구도도 보여줍니다. 그리고 '
#              '구성도 아래에 그 구성도의 내용을 설명하는 적절한 서술문들이 배치됩니다. ... BM을 전개하기 위해서 어떤 핵심 '
#              '자원들이 필요한지 서술한다. 사람, 기술, 특허, 제휴, 브랜드 '
#              '...</content><source>https://blog.naver.com/PostView.nhn?blogId=ahnmoon&logNo=222442155102</source></document>\n'
#              '<document><content>Amazon Music for Artists defines superfans '
#              'as, "a small, but extremely valuable, subset of your most '
#              'passionate Fans. On average, these listeners drive almost one '
#              'third of your total streams, and the majority will continue to '
#              'listen to your music in the next 30 days.". Spotify for Artists '
#              'writes: "There are fans, and then there are die '
#              '...</content><source>https://trolley.com/learning-center/what-are-superfans-why-are-they-the-talk-of-the-music-industry/</source></document>\n'
#              '<document><content>당신의 구독자, 단골, 광팬임을 자랑스러워하는 동시에, 당신과 당신 브랜드의 '
#              '가치를 다른 사람에게 자발적으로 홍보한다. 이 책은 이 시대 꾸준히 사랑받는 브랜드를 구축하기 위해 꼭 필요한 '
#              "'슈퍼팬 Superfans'을 만드는 19가지 전략을 "
#              '소개한다.</content><source>https://books.google.com/books/about/슈퍼팬.html?id=kdMnEAAAQBAJ</source></document>'}
# '\n---\n'
# "Output from node 'llm_answer':"
# '---'
# { 'answer': 'Superfans BM을 준비하기 위한 구체적인 전략이나 방법론으로는 비즈니스 모델 캔버스(Business Model '
#             'Canvas)를 사용하는 것이 언급되어 있습니다. 이 방법론은 다섯 가지 주요 요소인 CS(Customer '
#             'Segments), VP(Value Propositions), CH(Channels), CR(Customer '
#             'Relationships), R$(Revenue Streams)를 실현하기 위해 필요한 자원을 정의하는 데 '
#             '사용됩니다. 필요한 자원으로는 물리적, 재무적, 지적, 인적 자원이 포함됩니다. 또한, 핵심 자원으로 사람, 기술, '
#             '특허, 제휴, 브랜드 등이 필요하다고 서술되어 있습니다. (출처: '
#             'https://ggumttakji.tistory.com/13, '
#             'https://blog.naver.com/PostView.nhn?blogId=ahnmoon&logNo=222442155102)'}
# '\n---\n'
# relevance_check {'question': 'Superfans BM을 준비하기 위해 필요한 구체적인 전략이나 방법론은 무엇인가요?', 'context': '<document><content>글로벌 음악 산업의 해자가 될, Superfans BM 월간 엔터 Sep, \'24 Analyst 박수영 3772-7634 suyoung.park.0202@hanwha.com 해외 음악 산업 플레이어들의 최근 가장 큰 관심사는 "Superfans BM"을 어떻게 구축할 것인가 입니다. 오랜 기간 산업의 헤게모니가 코어 팬덤 생성 및 수익화였</content><source>https://www.bondweb.co.kr/_research/downloadPage.asp?number=797290&gn=1</source></document>\n<document><content>BM을 구축하는 데 가장 많이 쓰이는 도구가 바로 비즈니스 모델 캔버스(Business Model Canvas) ... 앞서 언급된 다섯 가지(CS, VP, CH, CR, R$)를 실현하기 위해 필요한 자원을 정의합니다. 주로 활용되는 자원으로는 물리적, 재무적, 지적, 인적 자원 측면에서 설정할 수 있고 ...</content><source>https://ggumttakji.tistory.com/13</source></document>\n<document><content>또한 웅진이 사업 추진을 위해 필요한 침대회사와의 제휴 구도도 보여줍니다. 그리고 구성도 아래에 그 구성도의 내용을 설명하는 적절한 서술문들이 배치됩니다. ... BM을 전개하기 위해서 어떤 핵심 자원들이 필요한지 서술한다. 사람, 기술, 특허, 제휴, 브랜드 ...</content><source>https://blog.naver.com/PostView.nhn?blogId=ahnmoon&logNo=222442155102</source></document>\n<document><content>Amazon Music for Artists defines superfans as, "a small, but extremely valuable, subset of your most passionate Fans. On average, these listeners drive almost one third of your total streams, and the majority will continue to listen to your music in the next 30 days.". Spotify for Artists writes: "There are fans, and then there are die ...</content><source>https://trolley.com/learning-center/what-are-superfans-why-are-they-the-talk-of-the-music-industry/</source></document>\n<document><content>당신의 구독자, 단골, 광팬임을 자랑스러워하는 동시에, 당신과 당신 브랜드의 가치를 다른 사람에게 자발적으로 홍보한다. 이 책은 이 시대 꾸준히 사랑받는 브랜드를 구축하기 위해 꼭 필요한 \'슈퍼팬 Superfans\'을 만드는 19가지 전략을 소개한다.</content><source>https://books.google.com/books/about/슈퍼팬.html?id=kdMnEAAAQBAJ</source></document>', 'answer': 'Superfans BM을 준비하기 위한 구체적인 전략이나 방법론으로는 비즈니스 모델 캔버스(Business Model Canvas)를 사용하는 것이 언급되어 있습니다. 이 방법론은 다섯 가지 주요 요소인 CS(Customer Segments), VP(Value Propositions), CH(Channels), CR(Customer Relationships), R$(Revenue Streams)를 실현하기 위해 필요한 자원을 정의하는 데 사용됩니다. 필요한 자원으로는 물리적, 재무적, 지적, 인적 자원이 포함됩니다. 또한, 핵심 자원으로 사람, 기술, 특허, 제휴, 브랜드 등이 필요하다고 서술되어 있습니다. (출처: https://ggumttakji.tistory.com/13, https://blog.naver.com/PostView.nhn?blogId=ahnmoon&logNo=222442155102)', 'relevance': 'notGrounded'}
# "Output from node 'relevance_check':"
# '---'
# { 'answer': 'Superfans BM을 준비하기 위한 구체적인 전략이나 방법론으로는 비즈니스 모델 캔버스(Business Model '
#             'Canvas)를 사용하는 것이 언급되어 있습니다. 이 방법론은 다섯 가지 주요 요소인 CS(Customer '
#             'Segments), VP(Value Propositions), CH(Channels), CR(Customer '
#             'Relationships), R$(Revenue Streams)를 실현하기 위해 필요한 자원을 정의하는 데 '
#             '사용됩니다. 필요한 자원으로는 물리적, 재무적, 지적, 인적 자원이 포함됩니다. 또한, 핵심 자원으로 사람, 기술, '
#             '특허, 제휴, 브랜드 등이 필요하다고 서술되어 있습니다. (출처: '
#             'https://ggumttakji.tistory.com/13, '
#             'https://blog.naver.com/PostView.nhn?blogId=ahnmoon&logNo=222442155102)',
#   'question': 'Superfans BM을 준비하기 위해 필요한 구체적인 전략이나 방법론은 무엇인가요?',
#   'relevance': 'grounded'}
# '\n---\n'

# %%
print(output["relevance_check"]["question"])
print(output["relevance_check"]["answer"])
print(output["relevance_check"]["relevance"])
# Out:
# Superfans BM을 준비하기 위해 필요한 구체적인 전략이나 방법론은 무엇인가요?
# Superfans BM을 준비하기 위한 구체적인 전략이나 방법론으로는 비즈니스 모델 캔버스(Business Model Canvas)를 사용하는 것이 언급되어 있습니다. 이 방법론은 다섯 가지 주요 요소인 CS(Customer Segments), VP(Value Propositions), CH(Channels), CR(Customer Relationships), R$(Revenue Streams)를 실현하기 위해 필요한 자원을 정의하는 데 사용됩니다. 필요한 자원으로는 물리적, 재무적, 지적, 인적 자원이 포함됩니다. 또한, 핵심 자원으로 사람, 기술, 특허, 제휴, 브랜드 등이 필요하다고 서술되어 있습니다. (출처: https://ggumttakji.tistory.com/13, https://blog.naver.com/PostView.nhn?blogId=ahnmoon&logNo=222442155102)
# grounded

# %% [markdown]
# ## LangSmith 추적
#
# - 추적: https://smith.langchain.com/public/ce7b4ea8-df34-4bb6-850e-afc8d12e75e6/r
